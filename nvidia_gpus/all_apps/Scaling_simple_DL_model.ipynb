# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline


# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
# fix random seed for reproducibility
np.random.seed(7)
# load pima indians dataset
#dataset = pd.read_csv("p100_only.csv", delimiter=",").values
# split into input (X) and output (Y) variables
#X = dataset[:,0:8]
#Y = dataset[:,8]
# create model
def my_model():
    model = Sequential()
    """
    #original simple dl model
    model.add(Dense(12, input_dim=112, kernel_initializer='normal',activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(1, activation='relu'))"""
    #early stopping, smaller layers, less layers
    model.add(Dense(120, input_dim=116, kernel_initializer='normal',activation='relu'))
    model.add(Dense(110, activation='relu'))
    #model.add(Dense(100, activation='relu'))
    #model.add(Dense(90, activation='relu'))
    #model.add(Dense(100, activation='relu'))
    #model.add(Dense(110, activation='relu'))
    model.add(Dense(110, activation='relu'))
    model.add(Dense(1, activation=None))
    # Compile model
    #mean absolute percentage error - indicating that we seek to minimize the mean percentage difference between 
    #predicted ipc and the actual ipc
    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])
    # Fit the model
    ## model.fit(X, Y, epochs=10, batch_size=10) ##works

    """
    # evaluate the model
    scores = model.evaluate(X, Y)
    print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))"""
    return model

# %%
print('sdf')
# Out:
# sdf

# %%
import glob
import os

basedir = "/Users/yzamora/active_learning/one_RANDOM_indices/"
outdir = "/Users/yzamora/power/nvidia_gpus/all_apps/best_deephyper_mls/"

for x_file in glob.glob(basedir + "X_train_Random_*per_one.npy"):
    pct = int(os.path.basename(x_file).split("_")[3].split("per")[0])
    y_file = basedir + "y_train_Random_" + str(pct) + "per_one.npy"
    
    X_train = np.load(x_file)
    y_train = np.load(y_file)
    model = my_model()
    #model.fit(X_train, y_train, epochs=2000, batch_size=10000, verbose=1,validation_data=(X_train,y_train))
    model.fit(X_train, y_train, epochs=100, batch_size=250, verbose=1,validation_data=(X_train,y_train))
    
    model_fname = outdir + "C_one_" + str(pct) + "-POST_unique.h5"
    model.save(model_fname)
# Out:
# Train on 2825 samples, validate on 2825 samples
# Epoch 1/100
# 2825/2825 [==============================] - 4s 1ms/step - loss: 0.4852 - mean_squared_error: 0.4852 - mean_absolute_error: 0.5587 - val_loss: 0.3191 - val_mean_squared_error: 0.3191 - val_mean_absolute_error: 0.4450
# Epoch 2/100
# 2825/2825 [==============================] - 0s 38us/step - loss: 0.2910 - mean_squared_error: 0.2910 - mean_absolute_error: 0.4054 - val_loss: 0.2755 - val_mean_squared_error: 0.2755 - val_mean_absolute_error: 0.3930
# Epoch 3/100
# 2825/2825 [==============================] - 0s 39us/step - loss: 0.2732 - mean_squared_error: 0.2732 - mean_absolute_error: 0.3830 - val_loss: 0.2630 - val_mean_squared_error: 0.2630 - val_mean_absolute_error: 0.3670
# Epoch 4/100
# 2825/2825 [==============================] - 0s 38us/step - loss: 0.2620 - mean_squared_error: 0.2620 - mean_absolute_error: 0.3703 - val_loss: 0.2635 - val_mean_squared_error: 0.2635 - val_mean_absolute_error: 0.3664
# Epoch 5/100
# ...

# %%
#need to get model for each size 
X_train = np.load('/Users/yzamora/active_learning/ALL_RANDOM_indices/X_train_RANDOM_10per_ALL.npy')
y_train = np.load('/Users/yzamora/active_learning/ALL_RANDOM_indices/y_train_RANDOM_10per_ALL.npy')
model = my_model()
model.fit(X_train, y_train, epochs=2000, batch_size=10000, verbose=1,validation_data=(X_train,y_train))
# Out:
# W1027 20:18:05.323296 4656489920 deprecation_wrapper.py:119] From /Users/yzamora/miniconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 2260 samples, validate on 2260 samples
# Epoch 1/2000
# 2260/2260 [==============================] - 1s 603us/step - loss: 0.6346 - mean_squared_error: 0.6346 - mean_absolute_error: 0.4771 - val_loss: 0.6209 - val_mean_squared_error: 0.6209 - val_mean_absolute_error: 0.4693
# Epoch 2/2000
# 2260/2260 [==============================] - 0s 12us/step - loss: 0.6209 - mean_squared_error: 0.6209 - mean_absolute_error: 0.4693 - val_loss: 0.6059 - val_mean_squared_error: 0.6059 - val_mean_absolute_error: 0.4620
# Epoch 3/2000
# ...

# %%
# Out:
# (15015, 116)

# %%
# Out:
# (2260, 116)
